# %%
from binance import client
from dotenv import load_dotenv
import os

# %%
load_dotenv()
API_KEY = os.getenv("API_KEY")
API_SECRET = os.getenv("API_SECRET")

# %%
api_key = API_KEY
api_secret = API_SECRET

# %%
cli = client.Client(api_key=api_key, api_secret=api_secret)

# %%
f"{cli.KLINE_INTERVAL_1HOUR}"
# Out:
# '1h'

# %%
klines_bnbbtc_interval_1_hour = cli.get_historical_klines(symbol="BNBBTC", interval=cli.KLINE_INTERVAL_1HOUR, start_str="10 day ago UTC")
klines_bnbbtc_interval_1_hour
# Out:
# [[1743076800000,
#   '0.00727900',
#   '0.00729000',
#   '0.00719600',
#   '0.00724100',
#   '4295.52600000',
#   1743080399999,
#   '30.98712238',
#   5128,
#   '999.05300000',
#   '7.20737492',
#   '0'],
#  [1743080400000,
#   '0.00724100',
#   '0.00733800',
#   '0.00723600',
#   '0.00733400',
#   '3216.72300000',
#   1743083999999,
#   '23.44454989',
#   4727,
#   '1396.87800000',
#   '10.19126831',
#   '0'],
#  [1743084000000,
#   '0.00733400',
#   '0.00733500',
#   '0.00729600',
#   '0.00730200',
#   '906.73600000',
#   1743087599999,
#   '6.63714184',
#   1411,
#   '419.97500000',
#   '3.07367340',
#   '0'],
#  [1743087600000,
#   '0.00730000',
#   '0.00733800',
#   '0.00728400',
#   '0.00732400',
#   '1477.98900000',
#   1743091199999,
#   '10.80852921',
#   2036,
#   '1044.44300000',
#   '7.63984440',
#   '0'],
#  [1743091200000,
#   '0.00732600',
#   '0.00733900',
#   '0.00731300',
#   '0.00731800',
#   '740.93400000',
#   1743094799999,
#   '5.42440588',
#   955,
# ...

# %%
account_info = cli.get_account()
account_info.values()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 account_info = cli.get_account()
#       2 account_info.values()
#
# File ~/personal_projects/python_projects/python-for-finances/venv/lib/python3.12/site-packages/binance/client.py:2166, in Client.get_account(self, **params)
#    2129 def get_account(self, **params):
#    2130     """Get current account information.
#    2131
#    2132     https://binance-docs.github.io/apidocs/spot/en/#account-information-user_data
#    (...)   2164
#    2165     """
# -> 2166     return self._get("account", True, data=params)
#
# File ~/personal_projects/python_projects/python-for-finances/venv/lib/python3.12/site-packages/binance/client.py:180, in Client._get(self, path, signed, version, **kwargs)
#     179 def _get(self, path, signed=False, version=BaseClient.PUBLIC_API_VERSION, **kwargs):
# ...
